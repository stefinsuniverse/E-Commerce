# %% [markdown]
# <a href="https://colab.research.google.com/github/stefinsuniverse/My.E-commerce/blob/main/yolo11_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OoeguceyLi7brKF9usr2")
project = rf.workspace("yolo11-xho8b").project("custom-workflow-object-detection-tggph")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 95.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Custom-Workflow-Object-Detection-1 in yolov11:: 100%|██████████| 18/18 [00:00<00:00, 4669.85it/s]

# %%
# !yolo detect train data=/content/Custom-Workflow-Object-Detection-1/data.yaml model=yolo11s.pt epochs=30 imgsz=640
# Out:
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo detect train data=/content/Custom-Workflow-Object-Detection-1/data.yaml model=yolov8s.pt epochs=30 imgsz=640
# Out:
# ...
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train3/weights/best.pt")  # build a new model from YAML

# Train the model
results = model("/content/Custom-Workflow-Object-Detection-1/test/images/wp3616604_jpg.rf.50711cd6cf70efec1c42f07dc828adb9.jpg", save=True)  # predict on an image
# Out:
# image 1/1 /content/Custom-Workflow-Object-Detection-1/test/images/wp3616604_jpg.rf.50711cd6cf70efec1c42f07dc828adb9.jpg: 640x640 1 Mountain, 1 Wheels, 1031.1ms
# Speed: 19.6ms preprocess, 1031.1ms inference, 51.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
